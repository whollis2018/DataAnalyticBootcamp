# %%
import pandas as pd
import numpy as np
location = "datasets/diamonds.csv"
df = pd.read_csv(location)

# %%
df.head(107)
# Out:
#      Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0             1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1             2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2             3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3             4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4             5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5             6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6             7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7             8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8             9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9            10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
# 10           11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# ...

# %%
df.tail(107)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53833       53834   0.72      Ideal     F     SI1   61.7   54.0   2737  5.77
# 53834       53835   0.70    Premium     E     VS2   62.5   59.0   2737  5.65
# 53835       53836   0.70    Premium     G    VVS2   59.6   61.0   2737  5.86
# 53836       53837   0.85    Premium     D     SI2   60.5   60.0   2737  6.11
# 53837       53838   0.77      Ideal     H     VS2   62.0   56.0   2738  5.86
# 53838       53839   0.80       Good     D     SI1   63.7   57.0   2738  5.88
# 53839       53840   0.71      Ideal     G     SI1   61.6   57.0   2738  5.72
# 53840       53841   0.71       Good     H    VVS2   60.4   63.0   2738  5.69
# 53841       53842   0.80  Very Good     H     SI1   63.8   56.0   2739  5.85
# 53842       53843   0.71      Ideal     H    VVS1   62.0   57.0   2739  5.71
# 53843       53844   0.57      Ideal     E    VVS1   61.8   56.0   2739  5.33
# ...

# %%
location = "datasets/diamonds.csv"
df = pd.read_csv(location)
df.head(200)
# Out:
#      Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0             1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1             2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2             3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3             4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4             5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5             6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6             7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7             8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8             9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9            10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
# 10           11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# ...

# %%
location = "datasets/diamonds.csv"
df = pd.read_csv(location)
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
location = "datasets/diamonds.csv"
df = pd.read_csv(location)
df.dtypesC
# Out:
# Unnamed: 0      int64
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# price           int64
# x             float64
# y             float64
# z             float64
# dtype: object

# %%
location = "datasets/diamonds.csv"
df = pd.read_csv(location)
df.count()
# Out:
# Unnamed: 0    53940
# carat         53940
# cut           53940
# color         53940
# clarity       53940
# depth         53940
# table         53940
# price         53940
# x             53940
# y             53940
# z             53940
# dtype: int64

# %%
location = "datasets/diamonds.csv"
df = pd.read_csv(location)
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
location = "datasets/diamonds.csv"
df = pd.read_csv(location)
df.groupby("depth").mean()
# Out:
#          Unnamed: 0     carat      table        price         x         y  \
# depth
# 43.0    7448.500000  1.045000  56.500000  4206.000000  6.425000  6.410000
# 44.0    6342.000000  1.000000  53.000000  4032.000000  6.310000  6.240000
# 50.8   16858.000000  1.430000  60.000000  6727.000000  7.730000  7.250000
# 51.0   36504.000000  0.300000  67.000000   945.000000  4.670000  4.620000
# 52.2   47776.000000  0.700000  65.000000  1895.000000  6.040000  5.990000
# 52.3   40767.000000  0.370000  61.000000  1166.000000  4.960000  4.910000
# 52.7   42257.000000  0.560000  70.000000  1293.000000  5.710000  5.570000
# 53.0     714.000000  1.020000  63.000000  2856.000000  6.840000  6.770000
# 53.1     444.000000  0.960000  63.000000  2815.000000  6.730000  6.650000
# 53.2   24642.000000  0.805000  61.500000  2988.500000  6.155000  6.080000
# 53.3     713.000000  0.980000  67.000000  2855.000000  6.820000  6.740000
# 53.4   49806.000000  0.730000  65.000000  2164.000000  6.190000  6.150000
# ...

# %%
location = "datasets/diamonds.csv"
pd.pivot_table(df, index=["carat"])
# Out:
#          Unnamed: 0      depth         price      table          x          y  \
# carat
# 0.20   28965.166667  61.100000    365.166667  59.333333   3.786667   3.753333
# 0.21   34659.000000  60.511111    380.222222  58.444444   3.874444   3.837778
# 0.22    6948.600000  61.620000    391.400000  60.400000   3.898000   3.848000
# 0.23   35756.993174  61.426621    486.143345  58.034130   3.946382   3.973379
# 0.24   31885.330709  61.599213    505.185039  57.488189   3.990157   4.019331
# 0.25   27251.905660  61.565566    550.924528  57.363208   4.062500   4.086934
# 0.26   25794.683794  61.677470    550.897233  56.911858   4.102688   4.124704
# 0.27   26385.497854  61.599142    574.759657  56.778970   4.159142   4.181588
# 0.28   29973.500000  61.526263    580.121212  56.863636   4.207172   4.233687
# 0.29   29105.807692  61.393077    601.192308  56.846154   4.262846   4.290538
# 0.30   31137.293779  61.914631    680.301843  57.134217   4.299443   4.308061
# ...

# %%
location = "datasets/diamonds.csv"
pd.pivot_table(df, index=["price"])
# Out:
#          Unnamed: 0     carat      depth      table         x         y  \
# price
# 326        1.500000  0.220000  60.650000  58.000000  3.920000  3.910000
# 327        3.000000  0.230000  56.900000  65.000000  4.050000  4.070000
# 334        4.000000  0.290000  62.400000  58.000000  4.200000  4.230000
# 335        5.000000  0.310000  63.300000  58.000000  4.340000  4.350000
# 336        6.500000  0.240000  62.550000  57.000000  3.945000  3.970000
# 337        8.500000  0.240000  63.500000  58.000000  3.970000  3.945000
# 338       10.000000  0.230000  59.400000  61.000000  4.000000  4.050000
# 339       11.000000  0.300000  64.000000  55.000000  4.250000  4.280000
# 340       12.000000  0.230000  62.800000  56.000000  3.930000  3.900000
# 342       13.000000  0.220000  60.400000  61.000000  3.880000  3.840000
# 344       14.000000  0.310000  62.200000  54.000000  4.350000  4.370000
# 345       15.500000  0.260000  60.550000  60.000000  4.085000  4.085000
# ...

# %%
location = "datasets/diamonds.csv"
pd.pivot_table(df, index=["price"]).mean()
# Out:
# Unnamed: 0    22526.727869
# carat             1.193426
# depth            61.707768
# table            57.662686
# x                 6.642782
# y                 6.645700
# z                 4.096475
# dtype: float64

# %%
location = "datasets/diamonds.csv"
pd.pivot_table(df, values=['carat'],index=["price"]).mean()
# Out:
# carat    1.193426
# dtype: float64

# %%
location = "datasets/diamonds.csv"
pd.pivot_table(df, values=['carat'],index=["price"]).max()
# Out:
# carat    5.01
# dtype: float64

# %%
location = "datasets/diamonds.csv"
pd.pivot_table(df, values=['carat'],index=["depth"]).max()
# Out:
# carat    2.32
# dtype: float64

# %%
location = "datasets/diamonds.csv"
pd.pivot_table(df, values=['carat'],index=["table"]).max()
# Out:
# carat    2.01
# dtype: float64
